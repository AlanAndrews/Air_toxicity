# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pb_parquet = pd.read_parquet('../supplementary_LEAD.parquet')
haps_parquet = pd.read_parquet('../supplementary_HAPS.parquet')
no_parquet = pd.read_parquet('../supplementary_NONOxNOy.parquet')
vocs_parquet = pd.read_parquet('../supplementary_VOCS.parquet')

# %%
pb_parquet.head(50).sort_values('Date.Local')
# Out:
#    State.Name  Date.Local  Parameter.Name  Arithmetic.Mean  X1st.Max.Value
# 30    Alabama  1980-01-01  Lead (TSP) STP             0.05            0.05
# 0     Alabama  1980-01-04  Lead (TSP) STP             0.04            0.04
# 31    Alabama  1980-01-04  Lead (TSP) STP             0.02            0.02
# 32    Alabama  1980-01-07  Lead (TSP) STP             4.31            4.31
# 33    Alabama  1980-01-10  Lead (TSP) STP             0.10            0.10
# 34    Alabama  1980-01-13  Lead (TSP) STP             0.05            0.05
# 1     Alabama  1980-01-16  Lead (TSP) STP             0.26            0.26
# 35    Alabama  1980-01-16  Lead (TSP) STP             0.59            0.59
# 36    Alabama  1980-01-22  Lead (TSP) STP             5.93            5.93
# 37    Alabama  1980-01-25  Lead (TSP) STP             0.69            0.69
# 2     Alabama  1980-01-28  Lead (TSP) STP             0.13            0.13
# ...

# %%
pb_parquet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 866835 entries, 0 to 866834
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   State.Name       866835 non-null  object
#  1   Date.Local       866835 non-null  object
#  2   Parameter.Name   866835 non-null  object
#  3   Arithmetic.Mean  866835 non-null  float64
#  4   X1st.Max.Value   866835 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 33.1+ MB

# %%
pb_parquet.describe()
# Out:
#        Arithmetic.Mean  X1st.Max.Value
# count    866835.000000   866835.000000
# mean          0.240588        0.240588
# std           1.112296        1.112296
# min          -0.007000       -0.007000
# 25%           0.010000        0.010000
# 50%           0.040000        0.040000
# 75%           0.160000        0.160000
# max         147.900000      147.900000

# %%
pb_parquet.groupby(['State.Name', 'Date.Local']).head()
# Out:
#            State.Name  Date.Local  Parameter.Name  Arithmetic.Mean  \
# 0             Alabama  1980-01-04  Lead (TSP) STP           0.0400
# 1             Alabama  1980-01-16  Lead (TSP) STP           0.2600
# 2             Alabama  1980-01-28  Lead (TSP) STP           0.1300
# 3             Alabama  1980-02-09  Lead (TSP) STP           0.1100
# 4             Alabama  1980-02-21  Lead (TSP) STP           0.1000
# ...               ...         ...             ...              ...
# 866830  West Virginia  2019-12-05  Lead (TSP) STP           0.0025
# 866831  West Virginia  2019-12-11  Lead (TSP) STP           0.0012
# 866832  West Virginia  2019-12-17  Lead (TSP) STP           0.0020
# 866833  West Virginia  2019-12-23  Lead (TSP) STP           0.0112
# 866834  West Virginia  2019-12-29  Lead (TSP) STP           0.0097
#
#         X1st.Max.Value
# 0               0.0400
# 1               0.2600
# 2               0.1300
# 3               0.1100
# 4               0.1000
# ...

# %%
pb_parquet['Date.Local'] = pb_parquet['Date.Local'].astype(str)

# %%
pb_parquet[['Date.Local.Year', 'Date.Local.Month', 'Date.Local.Day']] = pb_parquet['Date.Local'].str.split('-', expand=True)

# %%
pb_parquet.head()
# Out:
#   State.Name  Date.Local  Parameter.Name  Arithmetic.Mean  X1st.Max.Value  \
# 0    Alabama  1980-01-04  Lead (TSP) STP             0.04            0.04
# 1    Alabama  1980-01-16  Lead (TSP) STP             0.26            0.26
# 2    Alabama  1980-01-28  Lead (TSP) STP             0.13            0.13
# 3    Alabama  1980-02-09  Lead (TSP) STP             0.11            0.11
# 4    Alabama  1980-02-21  Lead (TSP) STP             0.10            0.10
#
#   Date.Local.Year Date.Local.Month Date.Local.Day
# 0            1980               01             04
# 1            1980               01             16
# 2            1980               01             28
# 3            1980               02             09
# 4            1980               02             21

# %%
pb_ag = pb_parquet.groupby(by=['State.Name', 'Date.Local.Year', 'Date.Local.Month']).describe()

# %%
pb_parquet.groupby(by=['State.Name', 'Date.Local.Year']).describe()
# Out:
#                            Arithmetic.Mean                             \
#                                      count      mean       std    min
# State.Name Date.Local.Year
# Alabama    1980                      101.0  1.231683  1.986881  0.020
#            1981                      304.0  0.823454  1.954147  0.000
#            1982                      360.0  0.845758  1.862625  0.016
#            1983                      527.0  0.865832  1.900166  0.000
#            1984                      437.0  1.219908  3.562002  0.000
# ...                                    ...       ...       ...    ...
# Wyoming    1981                       25.0  0.010560  0.008842  0.000
#            1982                       24.0  0.001000  0.003388  0.000
#            1983                       19.0  0.007247  0.002790  0.000
#            1984                       14.0  0.000000  0.000000  0.000
#            1985                        8.0  0.001337  0.003783  0.000
#
# ...

# %%
pb_ag.head()
# Out:
#                                             Arithmetic.Mean            \
#                                                       count      mean
# State.Name Date.Local.Year Date.Local.Month
# Alabama    1980            01                          13.0  0.949231
#                            02                          11.0  0.644545
#                            03                          13.0  1.133077
#                            04                          12.0  1.567500
#                            05                          12.0  1.150833
#
#                                                                            \
#                                                   std   min     25%   50%
# State.Name Date.Local.Year Date.Local.Month
# Alabama    1980            01                1.892258  0.02  0.0500  0.10
#                            02                0.777565  0.03  0.1050  0.24
#                            03                1.914764  0.03  0.2400  0.30
# ...

# %%
bool_check = pb_parquet['Arithmetic.Mean'] == pb_parquet['X1st.Max.Value']

# %%
bool_check.value_counts()
# Out:
# True    866835
# dtype: int64

# %%
haps_parquet.head(5)
# Out:
#   State.Name  Date.Local     Parameter.Name  Arithmetic.Mean  X1st.Max.Value
# 0    Alabama  1980-01-04  Arsenic (TSP) STP              0.0             0.0
# 1    Alabama  1980-01-16  Arsenic (TSP) STP              0.0             0.0
# 2    Alabama  1980-01-28  Arsenic (TSP) STP              0.0             0.0
# 3    Alabama  1980-02-09  Arsenic (TSP) STP              0.0             0.0
# 4    Alabama  1980-02-21  Arsenic (TSP) STP              0.0             0.0

# %%
no_parquet.head(5)
# Out:
#   State.Name  Date.Local     Parameter.Name  Arithmetic.Mean  X1st.Max.Value
# 0    Alabama  1980-01-01  Nitric oxide (NO)        54.458333           275.0
# 1    Alabama  1980-01-02  Nitric oxide (NO)       130.545455           279.0
# 2    Alabama  1980-01-03  Nitric oxide (NO)       122.333333           421.0
# 3    Alabama  1980-01-04  Nitric oxide (NO)         5.600000            12.0
# 4    Alabama  1980-01-05  Nitric oxide (NO)         6.166667            13.0

# %%
vocs_parquet.
# Out:
# (26601135, 5)
